# %%
# !git clone https://github.com/Karan-Malik/FaceMaskDetector
# Out:
# Cloning into 'FaceMaskDetector'...
# remote: Enumerating objects: 1543, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 1543 (delta 44), reused 72 (delta 31), pack-reused 1454
# Receiving objects: 100% (1543/1543), 84.40 MiB | 24.35 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
import numpy as np
import keras
import keras.backend as k
from keras.layers import Conv2D,MaxPooling2D,SpatialDropout2D,Flatten,Dropout,Dense
from keras.models import Sequential,load_model
#from keras.optimizers import adam
from keras.preprocessing import image
import cv2
import datetime

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Flatten())
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
        '/content/FaceMaskDetector/train',
        target_size=(150,150),
        batch_size=16 ,
        class_mode='binary')
# Out:
# Found 1314 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
        '/content/FaceMaskDetector/test',
        target_size=(150,150),
        batch_size=16,
        class_mode='binary')
# Out:
# Found 194 images belonging to 2 classes.

# %%
model_saved=model.fit_generator(
        training_set,
        epochs=10,
        validation_data=test_set,

        )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# Epoch 1/10
# 83/83 [==============================] - 52s 614ms/step - loss: 0.3376 - accuracy: 0.8166 - val_loss: 0.1498 - val_accuracy: 0.9536
# Epoch 2/10
# 83/83 [==============================] - 50s 599ms/step - loss: 0.1813 - accuracy: 0.9437 - val_loss: 0.1644 - val_accuracy: 0.9330
# Epoch 3/10
# 83/83 [==============================] - 49s 592ms/step - loss: 0.1238 - accuracy: 0.9619 - val_loss: 0.0760 - val_accuracy: 0.9845
# Epoch 4/10
# 83/83 [==============================] - 49s 590ms/step - loss: 0.1152 - accuracy: 0.9604 - val_loss: 0.0952 - val_accuracy: 0.9588
# Epoch 5/10
# 83/83 [==============================] - 49s 591ms/step - loss: 0.0849 - accuracy: 0.9665 - val_loss: 0.0800 - val_accuracy: 0.9639
# Epoch 6/10
# 83/83 [==============================] - 49s 594ms/step - loss: 0.0620 - accuracy: 0.9772 - val_loss: 0.0806 - val_accuracy: 0.9639
# Epoch 7/10
# 83/83 [==============================] - 49s 589ms/step - loss: 0.1329 - accuracy: 0.9536 - val_loss: 0.0994 - val_accuracy: 0.9588
# Epoch 8/10
# 83/83 [==============================] - 48s 579ms/step - loss: 0.0925 - accuracy: 0.9680 - val_loss: 0.0728 - val_accuracy: 0.9639
# Epoch 9/10
# 83/83 [==============================] - 49s 593ms/step - loss: 0.0560 - accuracy: 0.9810 - val_loss: 0.0728 - val_accuracy: 0.9588
# Epoch 10/10
# 83/83 [==============================] - 48s 579ms/step - loss: 0.0486 - accuracy: 0.9810 - val_loss: 0.1054 - val_accuracy: 0.9536

# %%
model.save('mymodel.h5',model_saved)

# %%
mymodel=load_model('mymodel.h5')

# %%
import cv2
import matplotlib.pyplot as plt

# %%
test_image=image.load_img('/content/WithMask.jpeg',
                          target_size=(150,150,3))
test_image
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
if(mymodel.predict(test_image)[0][0] == 0):
  print("With Mask")
else:
  print("Without Mask")
# Out:
# With Mask

# %%
im = cv2.imread('/content/WithMask.jpeg')
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
test_image=image.load_img('/content/WithoutMask.jpeg',
                          target_size=(150,150,3))
test_image
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
if(mymodel.predict(test_image)[0][0] == 1):
  print("With Mask")
else:
  print("Without Mask")
# Out:
# Without Mask

# %%
im = cv2.imread('/content/WithoutMask.jpeg')
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 9248)              0
#
#  dense (Dense)               (None, 100)               924900
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 944,393
# Trainable params: 944,393
# Non-trainable params: 0
# _________________________________________________________________
